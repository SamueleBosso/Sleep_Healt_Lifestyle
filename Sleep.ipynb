# %% [markdown]
# # SLEEP HEALT LIFESTYLE
#
#
# 1. **What is the percentage of people who report sleep disorders compared to those who do not report them?**
# 2. **Is there a relationship between age and the frequency of sleep disorders?**
# 3. **How do sleep disorders vary depending on the number of hours of sleep?**

# %%
#First import the libraries and the dataset in the csv file
import pandas as pd 
sleep = pd.read_csv(r"C:\Users\SamueleBosso\OneDrive - ITS Incom\Desktop\Sam\Progetti\SLEEP\sleep_health_lifestyle_dataset.csv", sep=",")
sleep
# Out:
#      Person ID  Gender  Age     Occupation  Sleep Duration (hours)  \
# 0            1    Male   29   Manual Labor                     7.4
# 1            2  Female   43        Retired                     4.2
# 2            3    Male   44        Retired                     6.1
# 3            4    Male   29  Office Worker                     8.3
# 4            5    Male   67        Retired                     9.1
# ..         ...     ...  ...            ...                     ...
# 395        396  Female   36        Student                     4.5
# 396        397  Female   45   Manual Labor                     6.0
# 397        398  Female   30        Student                     5.3
# 398        399  Female   41        Retired                    11.0
# 399        400    Male   37        Retired                     5.8
#
#      Quality of Sleep (scale: 1-10)  Physical Activity Level (minutes/day)  \
# 0                               7.0                                     41
# ...

# %% [markdown]
# # DATA CLEANING :

# %%
#check the null values
sleep.isnull().sum()
# Out:
# Person ID                                  0
# Gender                                     0
# Age                                        0
# Occupation                                 0
# Sleep Duration (hours)                     0
# Quality of Sleep (scale: 1-10)             0
# Physical Activity Level (minutes/day)      0
# Stress Level (scale: 1-10)                 0
# BMI Category                               0
# Blood Pressure (systolic/diastolic)        0
# Heart Rate (bpm)                           0
# Daily Steps                                0
# Sleep Disorder                           290
# dtype: int64

# %%
#replace the Nan values with "None"
sleep[sleep['Sleep Disorder'].isna()]
sleep['Sleep Disorder'].fillna('None', inplace=True)
sleep
# Out:
#      Person ID  Gender  Age     Occupation  Sleep Duration (hours)  \
# 0            1    Male   29   Manual Labor                     7.4
# 1            2  Female   43        Retired                     4.2
# 2            3    Male   44        Retired                     6.1
# 3            4    Male   29  Office Worker                     8.3
# 4            5    Male   67        Retired                     9.1
# ..         ...     ...  ...            ...                     ...
# 395        396  Female   36        Student                     4.5
# 396        397  Female   45   Manual Labor                     6.0
# 397        398  Female   30        Student                     5.3
# 398        399  Female   41        Retired                    11.0
# 399        400    Male   37        Retired                     5.8
#
#      Quality of Sleep (scale: 1-10)  Physical Activity Level (minutes/day)  \
# 0                               7.0                                     41
# ...

# %%
#check the duplicates values
sleep.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # DATA ESPLORATION :

# %%
#visualize the description of  differents data
print(sleep.describe())
# Out:
#         Person ID         Age  Sleep Duration (hours)  \
# count  400.000000  400.000000              400.000000
# mean   200.500000   39.950000                8.041250
# std    115.614301   14.038883                2.390787
# min      1.000000   18.000000                4.100000
# 25%    100.750000   29.000000                5.900000
# 50%    200.500000   40.000000                8.200000
# 75%    300.250000   49.000000               10.125000
# max    400.000000   90.000000               12.000000
#
#        Quality of Sleep (scale: 1-10)  Physical Activity Level (minutes/day)  \
# count                      400.000000                             400.000000
# mean                         6.125750                              64.985000
# std                          1.975733                              32.297874
# min                          1.000000                              10.000000
# 25%                          4.700000                              35.000000
# ...

# %%
# Visualize data type
print(sleep.dtypes)
# Out:
# Person ID                                  int64
# Gender                                    object
# Age                                        int64
# Occupation                                object
# Sleep Duration (hours)                   float64
# Quality of Sleep (scale: 1-10)           float64
# Physical Activity Level (minutes/day)      int64
# Stress Level (scale: 1-10)                 int64
# BMI Category                              object
# Blood Pressure (systolic/diastolic)       object
# Heart Rate (bpm)                           int64
# Daily Steps                                int64
# Sleep Disorder                            object
# dtype: object

# %% [markdown]
# # 1. **What is the percentage of people who report sleep disorders compared to those who do not report them?**

# %%
#count of differents type of disorders 
sleep['Sleep Disorder'].value_counts()
# Out:
# Sleep Disorder
# None           290
# Insomnia        79
# Sleep Apnea     31
# Name: count, dtype: int64

# %%
# Filter the data to include only  values in the 'Sleep Disorder' column differents from 'None'
Count_sleep_disorders = sleep[sleep['Sleep Disorder'] != 'None']

# Applica value_counts() solo alla colonna 'Sleep Disorder'
Sleep_disorders = Count_sleep_disorders['Sleep Disorder'].value_counts()

print(Sleep_disorders)
# Out:
# Sleep Disorder
# Insomnia       79
# Sleep Apnea    31
# Name: count, dtype: int64

# %%
# Filter the data to include only 'None' values in the 'Sleep Disorder' column
Count_sleep_disorders = sleep[sleep['Sleep Disorder'] == 'None']

# Apply value_counts() only to the 'Sleep Disorder' column
None_disorders = Count_sleep_disorders['Sleep Disorder'].value_counts()

print(None_disorders)
# Out:
# Sleep Disorder
# None    290
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


# Create the plot
sns.barplot(x='Sleep Disorder', y='Count', data=df, color='purple')
plt.title('Distribution of Sleep Disorders')
plt.xlabel('')
plt.ylabel('')

# Visualize the plot
plt.show()

# %% [markdown]
# # 2. **Is there a relationship between age and the frequency of sleep disorders?**

# %%
#let's start with the creation of differents age groups
Childhood = sleep[(sleep['Age'] >= 0) & (sleep['Age'] <= 14)].shape[0]
Young_Adults = sleep[(sleep['Age'] >= 14) & (sleep['Age'] <= 24)].shape[0]
Middle_Aged_Adults = sleep[(sleep['Age'] >= 24) & (sleep['Age'] <= 44)].shape[0]
Mature_Adults = sleep[(sleep['Age'] >= 44) & (sleep['Age'] <= 64)].shape[0]
Ancient = sleep[sleep['Age'] >= 65].shape[0]

# %%
# creation of the new coloumn called age_group
def age_group(age):
    if 0 <= age <= 14:
        return 'Childhood'
    elif 14 < age <= 24:
        return 'Young Adults'
    elif 24 < age <= 44:
        return 'Middle Aged Adults'
    elif 44 < age <= 64:
        return 'Mature Adults'
    else:
        return 'Ancient'

# %%
# we make union of age group in the dataset
sleep['Age Group'] = sleep['Age'].apply(age_group)
sleep.head()
# Out:
#    Person ID  Gender  Age     Occupation  Sleep Duration (hours)  \
# 0          1    Male   29   Manual Labor                     7.4
# 1          2  Female   43        Retired                     4.2
# 2          3    Male   44        Retired                     6.1
# 3          4    Male   29  Office Worker                     8.3
# 4          5    Male   67        Retired                     9.1
#
#    Quality of Sleep (scale: 1-10)  Physical Activity Level (minutes/day)  \
# 0                             7.0                                     41
# 1                             4.9                                     41
# 2                             6.0                                    107
# 3                            10.0                                     20
# 4                             9.5                                     19
#
#    Stress Level (scale: 1-10) BMI Category  \
# 0                           7        Obese
# 1                           5        Obese
# ...

# %%
# Grouping the data by Age Group and Sleep Disorder, counting occurrences, and unstacking for a tabular format
counts = sleep.groupby(['Age Group', 'Sleep Disorder']).size().unstack(fill_value=0)

# %%
# Plotting the frequency of sleep disorders by age group as a stacked bar chart
counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.xlabel('Age Group')  # Label for the X-axis
plt.ylabel('Frequency')  # Label for the Y-axis
plt.title('Frequency of Sleep Disorders by Age Group')  # Title of the chart
plt.legend(title='Sleep Disorder')  # Legend with a title
plt.tight_layout()  # Adjust layout for better visualization
plt.show()

# %% [markdown]
# # 3. **How do sleep disorders vary depending on the quality of sleep?**

# %%
# Visualize the coloumn 'Quality of sleep' 
sleep['Quality of Sleep (scale: 1-10)']
# Out:
# 0       7.0
# 1       4.9
# 2       6.0
# 3      10.0
# 4       9.5
#        ...
# 395     7.9
# 396     6.1
# 397     6.5
# 398     9.1
# 399     7.0
# Name: Quality of Sleep (scale: 1-10), Length: 400, dtype: float64

# %%
# Round the values in coloumn 'Quality of Sleep (scale: 1-10)' and convert in integer
sleep['Quality of Sleep (scale: 1-10)'] = sleep['Quality of Sleep (scale: 1-10)'].round(0).astype(int)

# Check values are trasformed correctly
print(sleep['Quality of Sleep (scale: 1-10)'].unique())
# Out:
# [ 7  5  6 10  4  3  9  8  1  2]

# %%
#let's check 
sleep['Quality of Sleep (scale: 1-10)']
# Out:
# 0       7
# 1       5
# 2       6
# 3      10
# 4      10
#        ..
# 395     8
# 396     6
# 397     6
# 398     9
# 399     7
# Name: Quality of Sleep (scale: 1-10), Length: 400, dtype: int32

# %%
#For the analisy just create a new coloumn for the quality sleep 
Low_Quality = sleep[sleep['Quality of Sleep (scale: 1-10)'] <= 4]
Moderate_Quality = sleep[(sleep['Quality of Sleep (scale: 1-10)'] > 5) & (sleep['Quality of Sleep (scale: 1-10)'] <= 7)]
High_Quality = sleep[sleep['Quality of Sleep (scale: 1-10)'] >= 8]

# %%
# creation of the new coloumn 'quality_of_sleep_group'
def quality_of_sleep_group(quality_score):
    if 1 <= quality_score <= 4:
        return "Low Quality"
    elif 5 <= quality_score <= 7:
        return "Moderate Quality"
    elif 8 <= quality_score <= 10:
        return "High Quality"
    else:
        return "Invalid Score"

# %%
# we make union of quality of sleep group in the dataset
sleep['Quality Group'] = sleep['Quality of Sleep (scale: 1-10)'].apply(quality_of_sleep_group)
sleep.head()
# Out:
#    Person ID  Gender  Age     Occupation  Sleep Duration (hours)  \
# 0          1    Male   29   Manual Labor                     7.4
# 1          2  Female   43        Retired                     4.2
# 2          3    Male   44        Retired                     6.1
# 3          4    Male   29  Office Worker                     8.3
# 4          5    Male   67        Retired                     9.1
#
#    Quality of Sleep (scale: 1-10)  Physical Activity Level (minutes/day)  \
# 0                               7                                     41
# 1                               5                                     41
# 2                               6                                    107
# 3                              10                                     20
# 4                              10                                     19
#
#    Stress Level (scale: 1-10) BMI Category  \
# 0                           7        Obese
# 1                           5        Obese
# ...

# %%
#let's show the differents values in the table 
total = sleep.groupby(['Quality Group', 'Sleep Disorder']).size().unstack(fill_value=0)
total
# Out:
# Sleep Disorder    Insomnia  None  Sleep Apnea
# Quality Group
# High Quality            18    75            7
# Low Quality             11    68            6
# Moderate Quality        50   147           18

# %%
# we create the visualization
colors = ['#FF5733', '#33FF57', '#3357FF']
total.plot(kind='barh', stacked=True, figsize=(10, 6), color= colors)
plt.ylabel('Quality Group') 
plt.xlabel('Frequency')     
plt.title('Frequency of Sleep Disorders by Quality Group')
plt.legend(title='Sleep Disorder') 
plt.tight_layout() 
plt.show()
